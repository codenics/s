# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib.colors import ListedColormap 
import imageio as img
N = 256
vals = np.ones((N, 4))
vals[:, 0] = np.zeros(256)
vals[:, 1] = np.zeros(256)
vals[:, 2] = np.linspace(0,1,256)

viridis = cm.get_cmap('viridis', 256)
newcolors = viridis(np.linspace(0, 1, 256))
pink = np.array([248/256, 24/256, 148/256, 1])
newcolors[:100, :] = pink
newcmp = ListedColormap(newcolors)
plt.imshow(image, cmap='Accent')
plt.colorbar()
plt.show()

plt.imshow(image, cmap='gray_r')

# %%
viridis = cm.get_cmap('viridis', 12)
print(viridis.colors)
# Out:
# [[0.267004 0.004874 0.329415 1.      ]
#  [0.283072 0.130895 0.449241 1.      ]
#  [0.262138 0.242286 0.520837 1.      ]
#  [0.220057 0.343307 0.549413 1.      ]
#  [0.177423 0.437527 0.557565 1.      ]
#  [0.143343 0.522773 0.556295 1.      ]
#  [0.119512 0.607464 0.540218 1.      ]
#  [0.166383 0.690856 0.496502 1.      ]
#  [0.319809 0.770914 0.411152 1.      ]
#  [0.525776 0.833491 0.288127 1.      ]
#  [0.762373 0.876424 0.137064 1.      ]
#  [0.993248 0.906157 0.143936 1.      ]]

# %%
viridis = cm.get_cmap('viridis', 2563)

# %%
print(viridis.colors)
# Out:
# [[0.267004 0.004874 0.329415 1.      ]
#  [0.267004 0.004874 0.329415 1.      ]
#  [0.267004 0.004874 0.329415 1.      ]
#  ...
#  [0.993248 0.906157 0.143936 1.      ]
#  [0.993248 0.906157 0.143936 1.      ]
#  [0.993248 0.906157 0.143936 1.      ]]

# %%
viridis = cm.get_cmap('winter', 12)
viridis.colors
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-197-bca77f82aaca> in <module>
#       1 viridis = cm.get_cmap('winter', 12)
# ----> 2 viridis.colors
#
# AttributeError: 'LinearSegmentedColormap' object has no attribute 'colors'

# %%
plt.set_cmap('Greys')
plt.imshow(image, cmap='Greys')

# %%
print(newcolors[0:5, :])
# Out:
# [[0.96875  0.09375  0.578125 1.      ]
#  [0.96875  0.09375  0.578125 1.      ]
#  [0.96875  0.09375  0.578125 1.      ]
#  [0.96875  0.09375  0.578125 1.      ]
#  [0.96875  0.09375  0.578125 1.      ]]

# %%
[248/256, 24/256, 148/256, 1]
# Out:
# [0.96875, 0.09375, 0.578125, 1]

# %%
x.shape, y.shape
# Out:
# ((256,), (256,))

# %%
plt.plot(x, ww)

# %%
zip?

# %%
pcolormesh?
# Out:
# Object `pcolormesh` not found.

# %%
virid = cm.get_cmap('viridis', 12)
viridis.colors.shape
viridis.colors
# Out:
# array([[0.267004, 0.004874, 0.329415, 1.      ],
#        [0.283072, 0.130895, 0.449241, 1.      ],
#        [0.262138, 0.242286, 0.520837, 1.      ],
#        [0.220057, 0.343307, 0.549413, 1.      ],
#        [0.177423, 0.437527, 0.557565, 1.      ],
#        [0.143343, 0.522773, 0.556295, 1.      ],
#        [0.119512, 0.607464, 0.540218, 1.      ],
#        [0.166383, 0.690856, 0.496502, 1.      ],
#        [0.319809, 0.770914, 0.411152, 1.      ],
#        [0.525776, 0.833491, 0.288127, 1.      ],
#        [0.762373, 0.876424, 0.137064, 1.      ],
#        [0.993248, 0.906157, 0.143936, 1.      ]])

# %%
x = np.linspace(-1,1,256)
y = np.exp(x*x)
z = np.exp(0.5*x*x)
ww = 1-(z+y)

# %%
N = 256
vals = np.ones((N, 4))
vals[:, 0] = np.zeros(256)
vals[:, 1] = np.zeros(256)
vals[:, 2] = np.linspace(0,1,256)
newcm = ListedColormap(vals)
viridis = cm.get_cmap('viridis', 256)
newcolors = viridis(np.linspace(0, 1, 256))
pink = np.array([248/256, 24/256, 148/256, 1])
newcolors[:25, :] = pink
newcmp = ListedColormap(newcolors)


def plot_examples(cms):
    """
    helper function to plot two colormaps
    """


    fig, axs = plt.subplots(1, 2, figsize=(6, 3), constrained_layout=True)

    plt.show()

plot_examples([viridis, newcmp])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-00f388669d59> in <module>
#      24     plt.show()
#      25
# ---> 26 plot_examples([viridis, newcmp])
#
# <ipython-input-129-00f388669d59> in plot_examples(cms)
#      20     fig, axs = plt.subplots(1, 2, figsize=(6, 3), constrained_layout=True)
#      21     for [ax, cmap] in zip(axs, cms):
# ---> 22         psm = ax.pcolormesh(image, cmap=cmap, rasterized=True, vmin=-4, vmax=4)
#      23         fig.colorbar(psm, ax=ax)
#      24     plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
# ...
